# %%
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn import tree   
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestClassifier 
from sklearn import metrics

# %%
data=pd.read_csv("titanic.csv")
data
# Out:
#      Unnamed: 0  PassengerId  Survived  Pclass  Sex   Age  SibSp  Parch  \
# 0             0          343         0       2    1  28.0      0      0
# 1             1           76         0       3    1  25.0      0      0
# 2             2          641         0       3    1  20.0      0      0
# 3             3          568         0       3    0  29.0      0      4
# 4             4          672         0       1    1  31.0      1      0
# ..          ...          ...       ...     ...  ...   ...    ...    ...
# 886         886           10         1       2    0  14.0      1      0
# 887         887           61         0       3    1  22.0      0      0
# 888         888          535         0       3    0  30.0      0      0
# 889         889          102         0       3    1  24.0      0      0
# 890         890          428         1       2    0  19.0      0      0
#
#          Ticket     Fare  Embarked Title  FamilySize
# ...

# %%
data.drop('Unnamed: 0',axis=1,inplace=True)

# %%
x=data.drop(["Survived", "Ticket", "Embarked","Title"], axis=1)
y= data["Survived"]
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.20,random_state=10)
dtree =DecisionTreeClassifier()  
dtree.fit(x_train, y_train)   
y_pred=dtree.predict(x_test)   
print("score:{}".format(accuracy_score(y_test, y_pred)))
# Out:
# score:0.7486033519553073

# %%
plt.figure(figsize=(30,20))
plot_tree(dtree,filled=True,feature_names = x.columns,proportion=True)
# Out:
# [Text(716.4202202138493, 1057.0, 'Sex <= 0.5\ngini = 0.469\nsamples = 100.0%\nvalue = [0.624, 0.376]'),
#  Text(363.09775967413447, 996.6, 'Pclass <= 2.5\ngini = 0.39\nsamples = 35.4%\nvalue = [0.266, 0.734]'),
#  Text(115.91853360488798, 936.2, 'Age <= 2.5\ngini = 0.1\nsamples = 18.7%\nvalue = [0.053, 0.947]'),
#  Text(102.28105906313647, 875.8, 'gini = 0.0\nsamples = 0.1%\nvalue = [1.0, 0.0]'),
#  Text(129.55600814663953, 875.8, 'Fare <= 26.125\ngini = 0.087\nsamples = 18.5%\nvalue = [0.045, 0.955]'),
#  Text(102.28105906313647, 815.4000000000001, 'PassengerId <= 48.0\ngini = 0.198\nsamples = 6.3%\nvalue = [0.111, 0.889]'),
#  Text(88.64358452138494, 755.0, 'gini = 0.0\nsamples = 0.1%\nvalue = [1.0, 0.0]'),
#  Text(115.91853360488798, 755.0, 'Age <= 55.5\ngini = 0.165\nsamples = 6.2%\nvalue = [0.091, 0.909]'),
#  Text(102.28105906313647, 694.6, 'FamilySize <= 1.5\ngini = 0.13\nsamples = 6.0%\nvalue = [0.07, 0.93]'),
# ...

# %%
x=data.drop(["Survived", "Ticket", "Embarked","Title"], axis=1)
y= data["Survived"]
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.20,random_state=10)
dtree =DecisionTreeClassifier(max_leaf_nodes=15,max_depth=15)  
dtree.fit(x_train, y_train)   
y_pred=dtree.predict(x_test)   
print("score:{}".format(accuracy_score(y_test, y_pred)))
# Out:
# score:0.8156424581005587

# %%
plt.figure(figsize=(30,20))
plot_tree(dtree,filled=True,feature_names = x.columns,proportion=True)
# Out:
# [Text(790.5, 1019.25, 'Sex <= 0.5\ngini = 0.469\nsamples = 100.0%\nvalue = [0.624, 0.376]'),
#  Text(372.0, 883.35, 'Pclass <= 2.5\ngini = 0.39\nsamples = 35.4%\nvalue = [0.266, 0.734]'),
#  Text(279.0, 747.45, 'gini = 0.1\nsamples = 18.7%\nvalue = [0.053, 0.947]'),
#  Text(465.0, 747.45, 'Fare <= 23.35\ngini = 0.5\nsamples = 16.7%\nvalue = [0.504, 0.496]'),
#  Text(279.0, 611.55, 'Age <= 27.5\ngini = 0.484\nsamples = 13.3%\nvalue = [0.411, 0.589]'),
#  Text(186.0, 475.65, 'Fare <= 8.04\ngini = 0.455\nsamples = 10.8%\nvalue = [0.351, 0.649]'),
#  Text(93.0, 339.75, 'gini = 0.355\nsamples = 5.5%\nvalue = [0.231, 0.769]'),
#  Text(279.0, 339.75, 'Fare <= 15.373\ngini = 0.499\nsamples = 5.3%\nvalue = [0.474, 0.526]'),
#  Text(186.0, 203.85000000000002, 'gini = 0.444\nsamples = 2.9%\nvalue = [0.667, 0.333]'),
#  Text(372.0, 203.85000000000002, 'PassengerId <= 89.5\ngini = 0.36\nsamples = 2.4%\nvalue = [0.235, 0.765]'),
# ...

# %%
X=data[['Age', 'Sex', 'SibSp', 'Parch','Pclass','Fare']] 
y=data['Survived'] 
x_train, x_test, y_train, y_test= train_test_split(X, y, test_size=0.25) 
clf=RandomForestClassifier(n_estimators=50,max_leaf_nodes=15,max_depth=20)  
clf.fit(x_train, y_train)  
y_pred=clf.predict(x_test)  
print("Accuracy:", metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.8116591928251121

# %%
clf=RandomForestClassifier(n_estimators=180,max_leaf_nodes=15,max_depth=20)  
clf.fit(x_train, y_train)  
y_pred=clf.predict(x_test)  
print("Accuracy:", metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.8430493273542601
